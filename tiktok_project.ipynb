# %%
import pandas as pd
import numpy as np
data = pd.read_csv('tiktok_dataset.csv')

# %% [markdown]
# # Understand the data - Inspect the data

# %%
data.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# * observation: There are 19,382 observations, but some of the variables are missing values, including the video transcripton, claim status, and all of the count variables.

# %%
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# * observation: Many of the count variables seem to have outliers at the high end of the distribution. They have very large standard deviations and maximum values that are very high compared to their quartile values.

# %% [markdown]
# # **Investigate the variables**

# %% [markdown]
# The first variable will be claim_status, how many value does it have and how many of each are in the data?

# %%
data['claim_status'].value_counts()
# Out:
# claim_status
# claim      9608
# opinion    9476
# Name: count, dtype: int64

# %% [markdown]
# * The counts of each claim status are quite balanced.

# %%
# What is the average view count of videos with "claim" status?
claims = data[data['claim_status'] == 'claim']
print('Mean video claim count:' , claims['video_view_count'].mean())
print('Median video claim count:' , claims['video_view_count'].median())
# Out:
# Mean video claim count: 501029.4527477102
# Median video claim count: 501555.0

# %%
# What is the average view count of videos with "opinion" status?
opinions = data[data['claim_status'] == 'opinion']
print('Mean video opinion count:' , opinions['video_view_count'].mean())
print('Median video opinion count:' , opinions['video_view_count'].median())
# Out:
# Mean video opinion count: 4956.43224989447
# Median video opinion count: 4953.0

# %% [markdown]
# *  The mean and the median within each claim category are close to one another, but there is a vast discrepancy between view counts for videos labeled as claims and videos labeled as opinions

# %%
data.groupby(['claim_status', 'author_ban_status']).count()[['#']]
# Out:
#                                    #
# claim_status author_ban_status
# claim        active             6566
#              banned             1439
#              under review       1603
# opinion      active             8817
#              banned              196
#              under review        463

# %% [markdown]
# * Notice here that active authors have more claims, these could mean:
#
#     1- that there is more supervision for active users
#
#     2- active users audiance report them more

# %% [markdown]
# * Also claim banned videos are higher than than opinion banned videos, which could mean:
#
#     1-  Claim videos are more strictly policed than opinion videos
#
#     2- Authors must comply with a stricter set of rules if they post a claim than if they post an opinion

# %%
data.groupby(['author_ban_status']).agg({
    'video_view_count' : ['count', 'mean', 'median'],
    'video_like_count' : ['count', 'mean', 'median'],
    'video_share_count': ['count', 'mean', 'median'],
})
# Out:
#                   video_view_count                          video_like_count  \
#                              count           mean    median            count
# author_ban_status
# active                       15383  215927.039524    8616.0            15383
# banned                        1635  445845.439144  448201.0             1635
# under review                  2066  392204.836399  365245.5             2066
#
#                                            video_share_count                \
#                             mean    median             count          mean
# author_ban_status
# active              71036.533836    2222.0             15383  14111.466164
# banned             153017.236697  105573.0              1635  29998.942508
# under review       128718.050339   71204.5              2066  25774.696999
#
#
#                     median
# author_ban_status
# active               437.0
# banned             14468.0
# under review        9444.0

# %% [markdown]
# * Banned authors and those under review get far more views, likes, and shares than active authors.
# * In most groups, the mean is much greater than the median, which indicates that there are some videos with very high engagement counts.

# %%
data['likes_per_view'] = data['video_like_count']/data['video_view_count']
data['comments_per_view'] = data['video_comment_count']/data['video_view_count']
data['shares_per_view'] = data['video_share_count']/data['video_view_count']

data.groupby(['claim_status', 'author_ban_status']).agg(
    {'likes_per_view': ['count', 'mean', 'median'],
     'comments_per_view': ['count', 'mean', 'median'],
     'shares_per_view': ['count', 'mean', 'median']})
# Out:
#                                likes_per_view                      \
#                                         count      mean    median
# claim_status author_ban_status
# claim        active                      6566  0.329542  0.326538
#              banned                      1439  0.345071  0.358909
#              under review                1603  0.327997  0.320867
# opinion      active                      8817  0.219744  0.218330
#              banned                       196  0.206868  0.198483
#              under review                 463  0.226394  0.228051
#
#                                comments_per_view                      \
#                                            count      mean    median
# claim_status author_ban_status
# claim        active                         6566  0.001393  0.000776
#              banned                         1439  0.001377  0.000746
#              under review                   1603  0.001367  0.000789
# ...

# %% [markdown]
# We know that videos by banned authors and those under review tend to get less views, likes, and shares than videos by non-banned authors. However, *when a video does get viewed*, its engagement rate is less related to author ban status and more related to its claim status.
#
# Also, we know that claim videos have a higher view rate than opinion videos, but this tells us that claim videos also have a higher rate of likes on average, so they are more favorably received as well. Furthermore, they receive more engagement via comments and shares than opinion videos.
#
# Note that for claim videos, banned authors have slightly higher likes/view and shares/view rates than active authors or those under review. However, for opinion videos, active authors and those under review both get higher engagement rates than banned authors in all categories.
